# %%
# this is a one line comment
print("hey guys, i'm checking one line comment\n")
# Out:
# hey guys, i'm checking one line comment

# %%
print("hey guys, i'm checking end of a line comment\n") # end of a line cooment
# Out:
# hey guys, i'm checking end of a line comment

# %%
"""
this is a comment
written in 
more than just one line
"""
print("hey guys, i'm chcking multi line cooment")
# Out:
# hey guys, i'm chcking multi line cooment
