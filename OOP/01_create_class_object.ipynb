# %%
# create a simple class
class MyClass:
    x = 5

# %%
# create an object
p1 = MyClass()
p2 = MyClass()
print(p1.x)
# Out:
# 5

# %%
# delete an object
print(p2.x)
del p2
print(p2.x)
# Out:
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # delete an object
#       2 print(p2.x)
#       3 del p2
# ----> 4 print(p2.x)
#
# NameError: name 'p2' is not defined
