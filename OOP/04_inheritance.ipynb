# %%
class Cars:
    def __init__(self, brand, score):
        self.brand = brand
        self.score = score
        
    def printInfoCar(self):
        print(self.brand, self.score)
        
class Motorcycle(Cars):
    def __init__(self, brand, score):
        cars.__init__(self, brand, score)

x = Motorcycle("BMW", "95")
x.printInfoCar()
# Out:
# BMW 95

# %%
class Person:
    def __init__(self, name, family, age = 1):
        self.name = name
        self.family = family
        self.age = age

     # def __str__(self):
     #    return f"{self.name}({self.family})"

class Employee(Person):
    def __init__(self, name, family, age):
        Person.__init__(self, name, family, age)

em = Employee("john", "wick", 25)
print(em.name)
print(em.family)
print(em.age)
# Out:
# john
# wick
# 25
