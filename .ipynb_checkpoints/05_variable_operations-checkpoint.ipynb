# %%
print("\n---- create variables ----")
a = 14
b = "john"
print("a is:", a)
print("b is:", b)
# Out:
# ---- create variables ----
# a is: 14
# b is: john

# %%
print("\n ---- create variables use many models ----")

print("camel cases is 'myVariableName'")
myVariableName = "John" # Camel Case

print("pascal Case is 'MyVariableName'")
MyVariableName = "John" # pascal Case

print("Snake Case is 'my_variable_name'")
my_variable_name = "John" # Snake Case
# Out:
#  ---- create variables use many models ----
# camel cases is 'myVariableName'
# pascal Case is 'MyVariableName'
# Snake Case is 'my_variable_name'

# %%
print("\n ---- casting variables ----")
x = 6
print("value X is {}".format(x))

num = 3
print("Number {} type is :".format(num), type(num))

num = str(3)
print("Number {} type is :".format(num), type(num))

"""
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
"""
# Out:
#  ---- casting variables ----
# value X is 6
# Number 3 type is : <class 'int'>
# Number 3 type is : <class 'str'>
# "\nx = str(3)    # x will be '3'\ny = int(3)    # y will be 3\nz = float(3)  # z will be 3.0\n"

# %%
print("\n --- case Sensitve variable ----")

m = 6
M = 12
print("m is: ", m)
print("M is: ", M)
# Out:
#  --- case Sensitve variable ----
# m is:  6
# M is:  12
