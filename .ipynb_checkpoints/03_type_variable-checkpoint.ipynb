# %%
# what is type method
a = 4
print(type(a))
# Out:
# <class 'int'>

# %%
b = "4"
print(type(b))
# Out:
# <class 'str'>

# %%
c = '4'
print(type(c))
# Out:
# <class 'str'>

# %%
msg = "hello"
print(type(msg))
# Out:
# <class 'str'>
