# %%
# iterators in tuple

mytuple = ("alireza", "ali", "reza")
item= iter(mytuple)
print(next(item))
print(next(item))
print(next(item))
# Out:
# alireza
# ali
# reza

# %%
# iterators in text
mystr = "alireza"
item = iter(mystr)
print(item)

# print(next(item))
# print(next(item))
# print(next(item))
# print(next(item))
# print(next(item))
# print(next(item))

# %%
# iterator in tuple with for
mytuple = ("alireza", "ali", "reza")

for x in mytuple:
  print(x)
# Out:
# alireza
# ali
# reza

# %%
# iterator in class

class MyNumbers:
  def __iter__(self):
    self.a = 1
    return self

  def __next__(self):
    x = self.a
    self.a += 1
    return x

myclass = MyNumbers()
myiter = iter(myclass)

print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
